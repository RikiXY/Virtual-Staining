# %% [markdown]
# # Coregistrazione di due immagini
# Il seguente notebook ha lo scopo di spiegare il processo seguito per la coregistrazione di due immagini. Questo step è necessario per eseguire l'allenamento di una rete neurale supervisionata.

# %% [markdown]
# ## 0. Passaggi preliminari

# %% [markdown]
# ### 0.1 Pacchetti necessari
# I pacchetti necessari all'avvio del notebook sono:
# - `cv2`
# - `numpy`
# - `matplotlib`

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 0.2 Funzioni utili

# %%
def show_side_hist(image_1, title_1, image_2, title_2, cmap='gray', figsize=(20, 20)):
    figure, subplots = plt.subplots(1, 2, figsize=figsize)

    subplots[0].set_title(title_1)
    # conversione vettore 1D
    subplots[0].hist(image_1.ravel(), bins=256, range=(0, 256), color='black', alpha=0.75)

    subplots[1].set_title(title_2)
    subplots[1].hist(image_2.ravel(), bins=256, range=(0, 256), color='black', alpha=0.75)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 1. Normalizzazione
# Gli algoritmi di **_Feature Matching_** individuano i _keypoint_ principalmente in zone ad alto contrasto, poiché queste aree presentano variazioni di intensità più marcate. Per questo motivo, una normalizzazione del contrasto può facilitare l’individuazione e la distinzione delle caratteristiche tra immagini diverse.
#
# **Nota**: _un keypoint è un punto caratteristico dell’immagine, tipicamente situato in regioni con forti variazioni di intensità (come angoli, bordi, ecc.), rilevato dagli algoritmi di feature detection per consentire il confronto tra immagini._
#
# Se l’istogramma dell’immagine è sbilanciato, ad esempio concentrato verso i toni scuri (neri) o chiari (bianchi), la rilevazione dei keypoint può risultare compromessa, riducendo l'efficacia del matching tra le immagini.

# %% [markdown]
# ## 2. Algoritmi di allineamento

# %% [markdown]
# ## 3. Filtri

# %% [markdown]
# ## 4. Allineamento
